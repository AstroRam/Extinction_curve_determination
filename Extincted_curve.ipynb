# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy import units as u
from specutils.spectra import Spectrum1D, SpectralRegion
from specutils.fitting import fit_generic_continuum
data = np.loadtxt('HD14818.txt')
x = data[:, 0]
y = data[:, 1]
flux=y*(u.erg / (u.cm ** 2 * u.s * u.AA))
spectral_axis = 1/x*u.AA
spectrum = Spectrum1D(flux, spectral_axis)
from matplotlib import pyplot as plt
plt.plot(spectrum.spectral_axis, spectrum.flux) 
plt.xlabel('Spectral Axis ({})'.format(spectrum.spectral_axis.unit)) 
plt.ylabel('Flux Axis({})'.format(spectrum.flux.unit)) 
plt.grid(True) 
#plt.savefig('Fluxvswavength_SWP18658LL',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')

# %%
flux=flux.to(u.erg / (u.cm ** 2 * u.s * u.micron))
spectral_axis=spectral_axis.to(u.micron)

# %%
spectral_axis
# Out:
# <Quantity [8.69126120e-08, 8.67861944e-08, 8.66600689e-08, ...,
#            2.99081342e-08, 2.98842791e-08, 2.98604621e-08] micron>

# %%
spectrum = Spectrum1D(flux, spectral_axis)
from matplotlib import pyplot as plt
plt.plot(spectrum.spectral_axis, spectrum.flux) 
plt.xlabel('1/λ(μm^-1)') 
plt.ylabel('Flux Axis({})'.format(spectrum.flux.unit)) 
plt.grid(True) 
plt.savefig('HD14818',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('extinct.txt')
x = data[:, 0]
y = data[:, 1]
plt.plot(x, y) 
#plt.xlabel('Spectral Axis ({})'.format(spectrum.spectral_axis.unit)) 
#plt.ylabel('Flux Axis({})'.format(spectrum.flux.unit)) 
plt.grid(True) 
#plt.savefig('Fluxvswavength_SWP18658LL',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('extincted.txt')
x = data[:, 0]
y = data[:, 1]
plt.plot(x, y) 
plt.xlabel('Spectral Axis ({})'.format(spectrum.spectral_axis.unit)) 
plt.ylabel('extinction') 
plt.grid(True) 
plt.savefig('extincted_1A',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('extincted1.txt')
x = data[:, 0]
y = data[:, 1]
plt.plot(x, y) 
plt.xlabel('Spectral Axis ({})'.format(spectrum.spectral_axis.unit)) 
plt.ylabel('extinction') 
plt.grid(True) 
plt.savefig('extincted_20A',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')
